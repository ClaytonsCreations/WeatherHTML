# %%
# Dependencies and Setup
import pandas as pd
from IPython.display import HTML

# %%
# File to Load (Remember to Change These)
cities = "/Resources/cities"


cities_db = pd.read_csv(cities)
cities_db
# Out:
#      Unnamed: 0           City  Temperature (in Farenheit)  Humidity  \
# 0             0        iqaluit                       29.93        92
# 1             1        rikitea                       74.82        77
# 2             2        mataura                       62.17        66
# 3             3      myitkyina                       67.42        89
# 4             4       cidreira                       61.77        65
# ..          ...            ...                         ...       ...
# 564         564         maradi                       86.07        13
# 565         565     shenjiamen                       65.10        78
# 566         566    guadalajara                       80.98        48
# 567         567          dukat                       10.96        92
# 568         568  khryashchevka                       40.57        84
#
#      Cloud Cover  Windspeed (in MPH)  Latitude  Longitude Country
# 0             90                8.01   63.7506   -68.5145      CA
# ...

# %%
citieshtml = cities_db.to_html()

# %%
citieshtml
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City</th>\n      <th>Temperature (in Farenheit)</th>\n      <th>Humidity</th>\n      <th>Cloud Cover</th>\n      <th>Windspeed (in MPH)</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Country</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>iqaluit</td>\n      <td>29.93</td>\n      <td>92</td>\n      <td>90</td>\n      <td>8.01</td>\n      <td>63.7506</td>\n      <td>-68.5145</td>\n      <td>CA</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>rikitea</td>\n      <td>74.82</td>\n      <td>77</td>\n      <td>38</td>\n      <td>15.75</td>\n      <td>-23.1203</td>\n      <td>-134.9692</td>\n      <td>PF</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>mataura</td>\n      <td>62.17</td>\n      <td>66</td>\n      <td>97</td>\n      <td>3.7
# ...

# %%
text_file = open("testingtable.html", "w")
text_file.write(testing)
text_file.close()
